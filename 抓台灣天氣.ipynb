# %% [markdown]
# <a href="https://colab.research.google.com/github/yuhrtm/Tibame_GAD245/blob/main/%E6%8A%93%E5%8F%B0%E7%81%A3%E5%A4%A9%E6%B0%A3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #抓中央氣象局的天氣API

# %%
import requests

# 定義 API URL
url = 'https://opendata.cwa.gov.tw/api/v1/rest/datastore/O-A0001-001?Authorization=CWA-EE6B8274-64E0-4976-9922-F433E68CB68E&format=JSON'

# 發送請求並取得 JSON 資料
try:
    response = requests.get(url)
    response.raise_for_status()  # 確保請求成功
    data = response.json()
except requests.exceptions.RequestException as e:
    print(f"無法取得資料: {e}")
    exit()

# 解析氣象資料
stations = data.get("records", {}).get("Station", [])
if not stations:
    print("無法找到測站資料")
    exit()

# 遍歷測站資料
for station in stations:
    # 提取測站基本資訊
    station_name = station.get("StationName", "未知測站")  # 測站名稱
    geo_info = station.get("GeoInfo", {})
    county = geo_info.get("CountyName", "未知縣市")  # 縣市
    town = geo_info.get("TownName", "未知鄉鎮")  # 鄉鎮

    # 提取氣象資料
    weather_elements = station.get("WeatherElement", {})
    weather = weather_elements.get("Weather", "無資料")  # 抓天氣狀態

    # 印出結果
    print(f"{county} {town} 的 {station_name} 天氣是 {weather}")
# Out:
# 屏東縣 滿州鄉 的 鼻頭 天氣是 陰
# 屏東縣 滿州鄉 的 興海 天氣是 陰
# 屏東縣 恆春鎮 的 後壁湖 天氣是 陰
# 屏東縣 恆春鎮 的 山海 天氣是 陰
# 屏東縣 車城鄉 的 竹坑 天氣是 陰
# 屏東縣 枋山鄉 的 加祿堂 天氣是 陰
# 臺南市 將軍區 的 鯤鯓國小 天氣是 多雲
# 屏東縣 枋寮鄉 的 下寮 天氣是 陰
# 屏東縣 佳冬鄉 的 塭仔 天氣是 陰
# 高雄市 林園區 的 汕尾 天氣是 陰
# 高雄市 小港區 的 鳳鼻頭 天氣是 陰
# 高雄市 梓官區 的 蚵仔寮 天氣是 陰
# 高雄市 彌陀區 的 南寮 天氣是 陰
# 高雄市 彌陀區 的 文安 天氣是 多雲
# 高雄市 茄萣區 的 興達 天氣是 多雲
# 臺南市 安南區 的 城西 天氣是 多雲
# 臺南市 安南區 的 四草 天氣是 多雲
# 臺南市 北門區 的 蘆竹溝 天氣是 陰
# 臺南市 北門區 的 蚵寮 天氣是 陰
# 高雄市 前鎮區 的 前鎮 天氣是 陰
# 新北市 貢寮區 的 澳底 天氣是 晴
# 澎湖縣 七美鄉 的 七美 天氣是 陰
# 澎湖縣 望安鄉 的 望安 天氣是 多雲
# 澎湖縣 湖西鄉 的 湖西 天氣是 多雲
# 連江縣 北竿鄉 的 北竿 天氣是 晴
# 臺北市 士林區 的 科教館 天氣是 晴
# 宜蘭縣 頭城鎮 的 大溪漁港 天氣是 晴
# 宜蘭縣 頭城鎮 的 石城 天氣是 晴
# 基隆市 安樂區 的 大武崙 天氣是 晴
# 新北市 萬里區 的 野柳 天氣是 晴
# 新北市 淡水區 的 淡水觀海 天氣是 晴
# 桃園市 大園區 的 竹圍 天氣是 晴
# 桃園市 新屋區 的 中大臨海站 天氣是 晴
# 新北市 石門區 的 石門 天氣是 晴
# 桃園市 觀音區 的 觀音工業區 天氣是 晴
# 新竹市 北區 的 海天一線 天氣是 晴
# 新竹市 香山區 的 香山濕地 天氣是 晴
# 新北市 瑞芳區 的 水湳洞 天氣是 晴
# 基隆市 中正區 的 八斗子 天氣是 晴
# 新竹縣 新豐鄉 的 外湖 天氣是 晴
# 苗栗縣 後龍鎮 的 海埔 天氣是 晴
# 苗栗縣 通霄鎮 的 通霄漁港 天氣是 晴
# 臺中市 大甲區 的 松柏 天氣是 晴
# 臺中市 大安區 的 溫寮 天氣是 晴
# 苗栗縣 竹南鎮 的 龍鳳 天氣是 晴
# 宜蘭縣 礁溪鄉 的 淡江大學蘭陽校園 天氣是 晴
# 屏東縣 林邊鄉 的 林邊 天氣是 陰
# 新北市 淡水區 的 六塊厝 天氣是 晴
# 新北市 三芝區 的 田寮 天氣是 晴
# 桃園市 觀音區 的 新興坑尾 天氣是 晴
# 宜蘭縣 蘇澳鎮 的 蘇澳 天氣是 晴
# 宜蘭縣 壯圍鄉 的 壯圍 天氣是 晴
# 宜蘭縣 頭城鎮 的 北關 天氣是 晴
# 彰化縣 伸港鄉 的 防潮門 天氣是 多雲
# 臺中市 龍井區 的 臺中電廠 天氣是 多雲
# 彰化縣 福興鄉 的 福寶 天氣是 陰
# 彰化縣 大城鄉 的 三豐 天氣是 陰
# 雲林縣 口湖鄉 的 箔子寮 天氣是 多雲
# 嘉義縣 布袋鎮 的 好美里 天氣是 陰
# 新北市 板橋區 的 板橋 天氣是 晴
# 花蓮縣 秀林鄉 的 秀林 天氣是 -99
# 花蓮縣 秀林鄉 的 和仁 天氣是 陰
# 連江縣 莒光鄉 的 東莒 天氣是 晴
# 澎湖縣 西嶼鄉 的 西嶼 天氣是 晴
# 澎湖縣 望安鄉 的 花嶼 天氣是 晴
# 金門縣 金沙鎮 的 金沙 天氣是 晴
# 金門縣 金寧鄉 的 金寧 天氣是 晴
# 金門縣 烏坵鄉 的 烏坵 天氣是 晴
# 臺北市 松山區 的 松山 天氣是 晴
# 苗栗縣 後龍鎮 的 高鐵苗栗 天氣是 晴
# 雲林縣 虎尾鎮 的 高鐵雲林 天氣是 晴
# 桃園市 龜山區 的 國一五楊N44K 天氣是 晴
# 基隆市 中正區 的 基隆嶼 天氣是 晴
# 臺東縣 蘭嶼鄉 的 蘭嶼高中 天氣是 陰
# 臺東縣 蘭嶼鄉 的 蘭嶼燈塔 天氣是 陰
# 新北市 石門區 的 白沙灣 天氣是 晴
# 高雄市 甲仙區 的 小林 天氣是 晴
# 桃園市 大溪區 的 大溪永福 天氣是 晴
# 宜蘭縣 大同鄉 的 玉蘭 天氣是 晴
# 宜蘭縣 五結鄉 的 五結 天氣是 晴
# 宜蘭縣 大同鄉 的 太平山 天氣是 晴
# 宜蘭縣 大同鄉 的 南山 天氣是 晴
# 宜蘭縣 員山鄉 的 雙連埤 天氣是 晴
# 宜蘭縣 頭城鎮 的 頭城 天氣是 晴
# 宜蘭縣 礁溪鄉 的 大礁溪 天氣是 晴
# 宜蘭縣 三星鄉 的 三星 天氣是 晴
# 宜蘭縣 員山鄉 的 內城 天氣是 晴
# 宜蘭縣 冬山鄉 的 冬山 天氣是 晴
# 宜蘭縣 礁溪鄉 的 礁溪 天氣是 晴
# 宜蘭縣 頭城鎮 的 龜山島 天氣是 晴
# 新北市 貢寮區 的 三貂角 天氣是 晴
# 宜蘭縣 羅東鎮 的 羅東 天氣是 晴
# 宜蘭縣 頭城鎮 的 鶯子嶺 天氣是 晴
# 宜蘭縣 壯圍鄉 的 大福 天氣是 晴
# 宜蘭縣 頭城鎮 的 坪林石牌 天氣是 晴
# 花蓮縣 秀林鄉 的 天祥 天氣是 晴
# 花蓮縣 壽豐鄉 的 東華 天氣是 陰
# 花蓮縣 壽豐鄉 的 鯉魚潭 天氣是 多雲
# 花蓮縣 秀林鄉 的 水源 天氣是 多雲
# 花蓮縣 鳳林鎮 的 鳳林山 天氣是 陰
# 花蓮縣 光復鄉 的 光復 天氣是 陰
# 花蓮縣 萬榮鄉 的 西林 天氣是 陰
# 花蓮縣 壽豐鄉 的 月眉山 天氣是 陰
# 花蓮縣 壽豐鄉 的 大坑 天氣是 陰
# 花蓮縣 豐濱鄉 的 加路蘭山 天氣是 陰
# 花蓮縣 壽豐鄉 的 水璉 天氣是 陰
# 花蓮縣 豐濱鄉 的 豐濱 天氣是 陰
# 花蓮縣 富里鄉 的 明里 天氣是 陰
# 花蓮縣 玉里鎮 的 玉里 天氣是 陰
# 花蓮縣 瑞穗鄉 的 舞鶴 天氣是 陰
# 花蓮縣 卓溪鄉 的 佳心 天氣是 陰
# 花蓮縣 光復鄉 的 富源 天氣是 陰
# 花蓮縣 吉安鄉 的 吉安光華 天氣是 陰
# 花蓮縣 鳳林鎮 的 鳳林 天氣是 陰
# 花蓮縣 卓溪鄉 的 卓溪 天氣是 陰
# 花蓮縣 新城鄉 的 新城 天氣是 多雲
# 花蓮縣 秀林鄉 的 富世 天氣是 多雲
# 花蓮縣 鳳林鎮 的 萬榮 天氣是 陰
# 花蓮縣 瑞穗鄉 的 瑞穗 天氣是 陰
# 花蓮縣 卓溪鄉 的 瑞穗林道 天氣是 陰
# 花蓮縣 壽豐鄉 的 蕃薯寮 天氣是 陰
# 花蓮縣 玉里鎮 的 德武 天氣是 陰
# 花蓮縣 玉里鎮 的 赤柯山 天氣是 陰
# 花蓮縣 富里鄉 的 東里 天氣是 陰
# 花蓮縣 秀林鄉 的 清水斷崖 天氣是 晴
# 花蓮縣 卓溪鄉 的 清水林道 天氣是 陰
# 花蓮縣 玉里鎮 的 安通山 天氣是 陰
# 花蓮縣 豐濱鄉 的 靜浦 天氣是 陰
# 臺東縣 長濱鄉 的 長濱 天氣是 陰
# 臺東縣 東河鄉 的 東河 天氣是 陰
# 臺東縣 綠島鄉 的 綠島 天氣是 陰
# 臺東縣 海端鄉 的 下馬 天氣是 多雲
# 臺東縣 海端鄉 的 向陽 天氣是 多雲
# 臺東縣 海端鄉 的 紅石 天氣是 陰
# 臺東縣 池上鄉 的 池上 天氣是 陰
# 臺東縣 鹿野鄉 的 鹿野 天氣是 陰
# 臺東縣 關山鎮 的 關山 天氣是 陰
# 臺東縣 達仁鄉 的 土阪 天氣是 陰
# 臺東縣 太麻里鄉 的 大溪山 天氣是 陰
# 臺東縣 達仁鄉 的 南田 天氣是 陰
# 臺東縣 太麻里鄉 的 金崙 天氣是 陰
# 臺東縣 太麻里鄉 的 太麻里 天氣是 陰
# 臺東縣 卑南鄉 的 知本 天氣是 陰
# 花蓮縣 富里鄉 的 富里 天氣是 陰
# 桃園市 中壢區 的 中壢 天氣是 晴
# 臺南市 柳營區 的 柳營 天氣是 多雲
# 新竹縣 關西鎮 的 關西 天氣是 晴
# 嘉義縣 阿里山鄉 的 新美 天氣是 晴
# 彰化縣 永靖鄉 的 永靖 天氣是 多雲
# 彰化縣 竹塘鄉 的 竹塘 天氣是 多雲
# 雲林縣 東勢鄉 的 雲林東勢 天氣是 多雲
# 屏東縣 車城鄉 的 車城 天氣是 陰
# 屏東縣 春日鄉 的 大漢山 天氣是 陰
# 屏東縣 枋山鄉 的 枋山 天氣是 陰
# 屏東縣 枋寮鄉 的 枋寮 天氣是 陰
# 屏東縣 枋山鄉 的 楓港 天氣是 陰
# 屏東縣 滿州鄉 的 檳榔 天氣是 陰
# 屏東縣 牡丹鄉 的 牡丹 天氣是 陰
# 屏東縣 滿州鄉 的 佳樂水 天氣是 陰
# 屏東縣 恆春鎮 的 墾丁 天氣是 陰
# 屏東縣 牡丹鄉 的 旭海 天氣是 陰
# 屏東縣 恆春鎮 的 貓鼻頭 天氣是 陰
# 屏東縣 恆春鎮 的 墾雷 天氣是 陰
# 屏東縣 牡丹鄉 的 四林格山 天氣是 陰
# 屏東縣 恆春鎮 的 大坪頂 天氣是 陰
# 屏東縣 恆春鎮 的 龍磐 天氣是 陰
# 屏東縣 獅子鄉 的 獅子 天氣是 陰
# 宜蘭縣 南澳鄉 的 東澳 天氣是 晴
# 宜蘭縣 南澳鄉 的 南澳 天氣是 晴
# 花蓮縣 秀林鄉 的 和中 天氣是 晴
# 宜蘭縣 大同鄉 的 翠峰湖 天氣是 晴
# 花蓮縣 秀林鄉 的 和平林道 天氣是 晴
# 花蓮縣 秀林鄉 的 和平 天氣是 晴
# 宜蘭縣 南澳鄉 的 樟樹山 天氣是 晴
# 宜蘭縣 頭城鎮 的 桃源谷 天氣是 晴
# 宜蘭縣 南澳鄉 的 西帽山 天氣是 晴
# 宜蘭縣 南澳鄉 的 西德山 天氣是 晴
# 新北市 烏來區 的 福山植物園 天氣是 晴
# 宜蘭縣 大同鄉 的 鴛鴦湖 天氣是 晴
# 宜蘭縣 大同鄉 的 白嶺 天氣是 晴
# 宜蘭縣 大同鄉 的 土場 天氣是 晴
# 宜蘭縣 員山鄉 的 員山 天氣是 晴
# 桃園市 蘆竹區 的 蘆竹 天氣是 晴
# 新竹縣 橫山鄉 的 橫山 天氣是 晴
# 新竹縣 新豐鄉 的 新豐 天氣是 晴
# 桃園市 觀音區 的 觀音 天氣是 晴
# 新竹縣 五峰鄉 的 雪霸 天氣是 晴
# 新竹縣 竹東鎮 的 竹東 天氣是 晴
# 桃園市 平鎮區 的 平鎮 天氣是 晴
# 桃園市 大溪區 的 大溪 天氣是 晴
# 苗栗縣 頭份市 的 頭份 天氣是 晴
# 新竹縣 寶山鄉 的 寶山 天氣是 晴
# 苗栗縣 獅潭鄉 的 獅潭 天氣是 晴
# 桃園市 楊梅區 的 楊梅 天氣是 晴
# 新竹縣 湖口鄉 的 湖口 天氣是 晴
# 桃園市 龍潭區 的 龍潭 天氣是 晴
# 新竹市 東區 的 新竹市東區 天氣是 晴
# 苗栗縣 三灣鄉 的 大河 天氣是 晴
# 臺中市 和平區 的 桃山A 天氣是 晴
# 臺中市 和平區 的 雪山東峰A 天氣是 晴
# 臺中市 和平區 的 雪山圈谷A 天氣是 晴
# 桃園市 龜山區 的 龜山 天氣是 晴
# 臺中市 和平區 的 審馬陣A 天氣是 晴
# 臺中市 和平區 的 南湖圈谷A 天氣是 晴
# 苗栗縣 苗栗市 的 苗栗 天氣是 晴
# 苗栗縣 銅鑼鄉 的 銅鑼 天氣是 晴
# 苗栗縣 西湖鄉 的 西湖 天氣是 晴
# 臺中市 大安區 的 大安 天氣是 晴
# 臺中市 后里區 的 后里 天氣是 晴
# 臺中市 豐原區 的 豐原 天氣是 晴
# 臺中市 潭子區 的 潭子 天氣是 晴
# 臺中市 清水區 的 清水 天氣是 晴
# 臺中市 外埔區 的 外埔 天氣是 晴
# 臺中市 龍井區 的 龍井 天氣是 多雲
# 彰化縣 伸港鄉 的 伸港 天氣是 多雲
# 苗栗縣 苑裡鎮 的 苑裡 天氣是 晴
# 臺中市 石岡區 的 石岡 天氣是 晴
# 臺中市 和平區 的 中坑 天氣是 晴
# 南投縣 魚池鄉 的 魚池 天氣是 晴
# 南投縣 國姓鄉 的 國姓 天氣是 晴
# 南投縣 仁愛鄉 的 仁愛 天氣是 晴
# 南投縣 水里鄉 的 水里 天氣是 晴
# 南投縣 集集鎮 的 集集 天氣是 晴
# 南投縣 名間鄉 的 名間 天氣是 晴
# 南投縣 仁愛鄉 的 萬大林道 天氣是 晴
# 南投縣 仁愛鄉 的 梅峰 天氣是 晴
# 南投縣 信義鄉 的 玉山風口 天氣是 -99
# 南投縣 仁愛鄉 的 小奇萊 天氣是 晴
# 南投縣 仁愛鄉 的 奇萊稜線A 天氣是 晴
# 臺中市 大里區 的 大里 天氣是 晴
# 臺中市 烏日區 的 烏日 天氣是 晴
# 臺中市 西屯區 的 西屯 天氣是 晴
# 臺中市 南屯區 的 南屯 天氣是 晴
# 彰化縣 福興鄉 的 福興 天氣是 多雲
# 彰化縣 秀水鄉 的 秀水 天氣是 多雲
# 彰化縣 埔鹽鄉 的 埔鹽 天氣是 多雲
# 彰化縣 埔心鄉 的 埔心 天氣是 多雲
# 彰化縣 田尾鄉 的 田尾 天氣是 多雲
# 彰化縣 埤頭鄉 的 埤頭 天氣是 多雲
# 彰化縣 社頭鄉 的 社頭 天氣是 晴
# 彰化縣 二水鄉 的 二水 天氣是 晴
# 苗栗縣 造橋鄉 的 造橋 天氣是 晴
# 新竹縣 尖石鄉 的 梅花 天氣是 晴
# 新北市 坪林區 的 坪林 天氣是 晴
# 新北市 雙溪區 的 泰平 天氣是 晴
# 新竹縣 峨眉鄉 的 峨眉 天氣是 晴
# 苗栗縣 竹南鎮 的 竹南 天氣是 晴
# 苗栗縣 南庄鄉 的 南庄 天氣是 晴
# 新北市 汐止區 的 五指山 天氣是 晴
# 新北市 汐止區 的 汐止 天氣是 晴
# 新北市 三峽區 的 三峽 天氣是 晴
# 臺北市 信義區 的 信義 天氣是 晴
# 臺北市 文山區 的 文山 天氣是 晴
# 新北市 新莊區 的 新莊 天氣是 晴
# 新北市 樹林區 的 山佳 天氣是 晴
# 新北市 烏來區 的 桶後 天氣是 晴
# 新北市 雙溪區 的 雙溪 天氣是 晴
# 宜蘭縣 大同鄉 的 多加屯 天氣是 晴
# 新北市 瑞芳區 的 鼻頭角 天氣是 晴
# 新北市 萬里區 的 大坪 天氣是 晴
# 新北市 金山區 的 三和 天氣是 晴
# 新北市 金山區 的 金山 天氣是 晴
# 新北市 石碇區 的 石碇 天氣是 晴
# 桃園市 復興區 的 復興 天氣是 晴
# 桃園市 桃園區 的 桃園 天氣是 晴
# 桃園市 八德區 的 八德 天氣是 晴
# 臺北市 內湖區 的 內湖 天氣是 晴
# 新北市 中和區 的 中和 天氣是 晴
# 基隆市 暖暖區 的 暖暖 天氣是 晴
# 臺北市 士林區 的 天母 天氣是 晴
# 臺北市 士林區 的 社子 天氣是 晴
# 臺北市 北投區 的 大屯山 天氣是 晴
# 新北市 八里區 的 八里 天氣是 晴
# 新北市 蘆洲區 的 蘆洲 天氣是 晴
# 新北市 土城區 的 土城 天氣是 晴
# 新北市 鶯歌區 的 鶯歌 天氣是 晴
# 新北市 永和區 的 永和 天氣是 晴
# 新北市 瑞芳區 的 五分山 天氣是 晴
# 臺北市 士林區 的 平等 天氣是 晴
# 新北市 林口區 的 林口 天氣是 晴
# 新北市 深坑區 的 深坑 天氣是 晴
# 基隆市 七堵區 的 七堵 天氣是 晴
# 新北市 五股區 的 五股 天氣是 晴
# 新北市 新店區 的 屈尺 天氣是 晴
# 新北市 三重區 的 三重 天氣是 晴
# 臺北市 北投區 的 石牌 天氣是 晴
# 臺東縣 金峰鄉 的 金峰嘉蘭 天氣是 陰
# 臺東縣 延平鄉 的 延平 天氣是 陰
# 臺東縣 長濱鄉 的 石寧山 天氣是 陰
# 臺東縣 東河鄉 的 七塊厝 天氣是 陰
# 臺東縣 臺東市 的 知本(水試所) 天氣是 陰
# 臺東縣 太麻里鄉 的 香蘭 天氣是 陰
# 臺東縣 大武鄉 的 加津林 天氣是 陰
# 臺東縣 達仁鄉 的 勝林山 天氣是 陰
# 臺東縣 大武鄉 的 山豬窟 天氣是 陰
# 臺東縣 太麻里鄉 的 歷坵 天氣是 陰
# 臺東縣 卑南鄉 的 檳榔四格山 天氣是 陰
# 臺東縣 太麻里鄉 的 金崙山 天氣是 陰
# 臺東縣 成功鎮 的 都歷 天氣是 陰
# 臺東縣 鹿野鄉 的 瑞和 天氣是 陰
# 臺東縣 達仁鄉 的 達仁林場 天氣是 陰
# 屏東縣 牡丹鄉 的 牡丹池山 天氣是 陰
# 屏東縣 牡丹鄉 的 高士 天氣是 陰
# 屏東縣 來義鄉 的 白鷺 天氣是 陰
# 屏東縣 獅子鄉 的 內獅 天氣是 陰
# 屏東縣 獅子鄉 的 丹路 天氣是 陰
# 屏東縣 滿州鄉 的 九棚 天氣是 陰
# 屏東縣 滿州鄉 的 滿州 天氣是 陰
# 屏東縣 車城鄉 的 保力 天氣是 陰
# 屏東縣 滿州鄉 的 南仁湖 天氣是 陰
# 南投縣 仁愛鄉 的 合歡山 天氣是 晴
# 臺中市 北屯區 的 大坑 天氣是 晴
# 彰化縣 溪湖鎮 的 溪湖 天氣是 多雲
# 彰化縣 員林市 的 員林 天氣是 晴
# 南投縣 草屯鎮 的 草屯 天氣是 晴
# 彰化縣 芬園鄉 的 芬園 天氣是 晴
# 新竹縣 新埔鎮 的 打鐵坑 天氣是 晴
# 臺中市 東勢區 的 東勢 天氣是 晴
# 南投縣 竹山鎮 的 竹山 天氣是 晴
# 苗栗縣 泰安鄉 的 馬都安 天氣是 晴
# 苗栗縣 頭屋鄉 的 明德 天氣是 晴
# 苗栗縣 通霄鎮 的 通霄 天氣是 晴
# 臺中市 神岡區 的 神岡 天氣是 晴
# 苗栗縣 卓蘭鎮 的 卓蘭 天氣是 晴
# 臺中市 新社區 的 新社 天氣是 晴
# 南投縣 埔里鎮 的 埔里 天氣是 晴
# 南投縣 信義鄉 的 信義 天氣是 晴
# 南投縣 仁愛鄉 的 昆陽 天氣是 晴
# 南投縣 仁愛鄉 的 廬山 天氣是 晴
# 花蓮縣 秀林鄉 的 大禹嶺 天氣是 晴
# 南投縣 信義鄉 的 神木村 天氣是 晴
# 臺中市 大雅區 的 大雅(中科園區) 天氣是 晴
# 南投縣 南投市 的 南投 天氣是 晴
# 彰化縣 花壇鄉 的 花壇 天氣是 多雲
# 彰化縣 線西鄉 的 線西 天氣是 多雲
# 臺中市 霧峰區 的 霧峰 天氣是 晴
# 雲林縣 崙背鄉 的 崙背 天氣是 多雲
# 嘉義縣 竹崎鄉 的 奮起湖 天氣是 晴
# 雲林縣 虎尾鎮 的 虎尾 天氣是 晴
# 雲林縣 四湖鄉 的 四湖 天氣是 多雲
# 雲林縣 口湖鄉 的 宜梧 天氣是 多雲
# 臺南市 下營區 的 下營 天氣是 多雲
# 嘉義縣 義竹鄉 的 東後寮 天氣是 多雲
# 臺南市 東山區 的 東河 天氣是 多雲
# 臺南市 佳里區 的 佳里 天氣是 多雲
# 彰化縣 二林鎮 的 二林 天氣是 陰
# 臺南市 白河區 的 白河 天氣是 多雲
# 嘉義縣 番路鄉 的 番路 天氣是 晴
# 臺南市 新營區 的 新營 天氣是 多雲
# 臺南市 將軍區 的 將軍 天氣是 多雲
# 雲林縣 褒忠鄉 的 褒忠 天氣是 多雲
# 嘉義縣 溪口鄉 的 溪口 天氣是 晴
# 雲林縣 二崙鄉 的 二崙 天氣是 多雲
# 嘉義縣 竹崎鄉 的 竹崎 天氣是 晴
# 嘉義縣 中埔鄉 的 中埔 天氣是 晴
# 臺南市 鹽水區 的 鹽水 天氣是 多雲
# 臺南市 學甲區 的 學甲 天氣是 多雲
# 臺南市 後壁區 的 後壁 天氣是 多雲
# 雲林縣 西螺鎮 的 西螺 天氣是 多雲
# 雲林縣 土庫鎮 的 土庫 天氣是 晴
# 嘉義縣 大林鎮 的 大林 天氣是 晴
# 嘉義縣 東石鄉 的 東石 天氣是 多雲
# 嘉義縣 水上鄉 的 水上 天氣是 多雲
# 嘉義市 東區 的 嘉義市東區 天氣是 晴
# 臺南市 白河區 的 關子嶺 天氣是 晴
# 臺南市 新化區 的 虎頭埤 天氣是 晴
# 臺南市 歸仁區 的 媽廟 天氣是 晴
# 臺南市 龍崎區 的 崎頂 天氣是 晴
# 臺南市 新市區 的 新市 天氣是 晴
# 臺南市 南化區 的 北寮 天氣是 晴
# 臺南市 善化區 的 善化 天氣是 晴
# 高雄市 桃源區 的 復興 天氣是 晴
# 臺南市 六甲區 的 王爺宮 天氣是 多雲
# 臺南市 大內區 的 大內 天氣是 晴
# 高雄市 阿蓮區 的 阿蓮 天氣是 多雲
# 臺南市 北區 的 臺南市北區 天氣是 晴
# 臺南市 南區 的 臺南市南區 天氣是 多雲
# 臺南市 安平區 的 安平 天氣是 多雲
# 臺南市 麻豆區 的 麻豆 天氣是 多雲
# 臺南市 安定區 的 安定 天氣是 多雲
# 臺南市 山上區 的 山上 天氣是 晴
# 臺南市 關廟區 的 關廟 天氣是 晴
# 臺南市 官田區 的 官田 天氣是 多雲
# 臺南市 西港區 的 西港 天氣是 多雲
# 臺南市 仁德區 的 仁德 天氣是 晴
# 臺南市 左鎮區 的 左鎮 天氣是 晴
# 嘉義縣 大埔鄉 的 表湖 天氣是 晴
# 屏東縣 泰武鄉 的 舊泰武 天氣是 陰
# 高雄市 茂林區 的 萬山 天氣是 晴
# 高雄市 六龜區 的 六龜 天氣是 晴
# 屏東縣 里港鄉 的 里港 天氣是 多雲
# 高雄市 左營區 的 左營 天氣是 陰
# 屏東縣 東港鎮 的 東港 天氣是 陰
# 屏東縣 竹田鄉 的 竹田 天氣是 陰
# 屏東縣 萬丹鄉 的 萬丹 天氣是 陰
# 屏東縣 霧臺鄉 的 阿禮 天氣是 多雲
# 屏東縣 瑪家鄉 的 瑪家 天氣是 多雲
# 高雄市 大樹區 的 溪埔 天氣是 多雲
# 高雄市 美濃區 的 美濃 天氣是 晴
# 屏東縣 三地門鄉 的 尾寮山 天氣是 多雲
# 高雄市 燕巢區 的 阿公店 天氣是 多雲
# 高雄市 內門區 的 內門 天氣是 晴
# 屏東縣 春日鄉 的 春日 天氣是 陰
# 屏東縣 萬巒鄉 的 來義 天氣是 陰
# 高雄市 田寮區 的 古亭坑 天氣是 晴
# 屏東縣 琉球鄉 的 琉球嶼 天氣是 陰
# 高雄市 鳳山區 的 鳳山 天氣是 陰
# 屏東縣 屏東市 的 屏東 天氣是 多雲
# 屏東縣 鹽埔鄉 的 鹽埔 天氣是 多雲
# 高雄市 小港區 的 鳳森 天氣是 陰
# 屏東縣 萬巒鄉 的 赤山 天氣是 多雲
# 屏東縣 內埔鄉 的 三地門 天氣是 多雲
# 屏東縣 潮州鎮 的 潮州 天氣是 陰
# 高雄市 新興區 的 新興 天氣是 陰
# 高雄市 湖內區 的 湖內 天氣是 多雲
# 高雄市 永安區 的 永安 天氣是 多雲
# 高雄市 大社區 的 大社 天氣是 多雲
# 高雄市 梓官區 的 梓官 天氣是 多雲
# 高雄市 路竹區 的 路竹 天氣是 多雲
# 高雄市 茄萣區 的 茄萣 天氣是 多雲
# 高雄市 岡山區 的 岡山 天氣是 多雲
# 高雄市 彌陀區 的 彌陀 天氣是 多雲
# 高雄市 橋頭區 的 橋頭 天氣是 多雲
# 高雄市 仁武區 的 仁武 天氣是 多雲
# 高雄市 三民區 的 三民 天氣是 陰
# 高雄市 鼓山區 的 鼓山 天氣是 陰
# 高雄市 苓雅區 的 苓雅 天氣是 陰
# 高雄市 旗山區 的 旗山 天氣是 晴
# 屏東縣 長治鄉 的 長治 天氣是 多雲
# 屏東縣 麟洛鄉 的 麟洛 天氣是 多雲
# 屏東縣 新埤鄉 的 新埤 天氣是 陰
# 屏東縣 南州鄉 的 南州 天氣是 陰
# 屏東縣 佳冬鄉 的 佳冬 天氣是 陰
# 屏東縣 高樹鄉 的 高樹 天氣是 多雲
# 屏東縣 九如鄉 的 九如 天氣是 多雲
# 高雄市 大寮區 的 大寮 天氣是 陰
# 屏東縣 新園鄉 的 新園 天氣是 陰
# 屏東縣 崁頂鄉 的 崁頂 天氣是 陰
# 高雄市 林園區 的 林園 天氣是 陰
# 彰化縣 溪州鄉 的 溪州 天氣是 多雲
# 雲林縣 斗南鎮 的 斗南 天氣是 晴
# 雲林縣 斗六市 的 斗六 天氣是 晴
# 嘉義縣 朴子市 的 朴子 天氣是 多雲
# 雲林縣 北港鎮 的 北港 天氣是 多雲
# 嘉義縣 太保市 的 太保 天氣是 多雲
# 雲林縣 林內鄉 的 林內 天氣是 晴
# 彰化縣 大城鄉 的 大城 天氣是 陰
# 嘉義縣 民雄鄉 的 民雄 天氣是 晴
# 雲林縣 大埤鄉 的 大埤 天氣是 晴
# 雲林縣 莿桐鄉 的 莿桐 天氣是 晴
# 雲林縣 臺西鄉 的 臺西 天氣是 多雲
# 雲林縣 水林鄉 的 水林 天氣是 多雲
# 雲林縣 元長鄉 的 元長 天氣是 晴
# 嘉義縣 布袋鎮 的 布袋 天氣是 陰
# 嘉義縣 鹿草鄉 的 鹿草 天氣是 多雲
# 嘉義縣 六腳鄉 的 六腳 天氣是 多雲
# 嘉義縣 新港鄉 的 新港 天氣是 晴
# 嘉義縣 梅山鄉 的 嘉義梅山 天氣是 晴
# 嘉義縣 阿里山鄉 的 里佳 天氣是 晴
# 嘉義縣 阿里山鄉 的 達邦 天氣是 晴
# 臺南市 白河區 的 鹿寮 天氣是 多雲
# 嘉義縣 阿里山鄉 的 茶山 天氣是 晴
# 雲林縣 古坑鄉 的 棋山 天氣是 晴
# 雲林縣 水林鄉 的 蔦松 天氣是 多雲
# 臺南市 北門區 的 北門 天氣是 陰

# %% [markdown]
# ---

# %% [markdown]
# #用pandas 篩選晴天的地方

# %%
import requests
import pandas as pd


# 將資料轉換為 Pandas DataFrame
data_list = []
for station in stations:
    station_name = station.get("StationName", "未知測站")
    county = station.get("GeoInfo", {}).get("CountyName", "未知縣市")
    town = station.get("GeoInfo", {}).get("TownName", "未知鄉鎮")
    weather = station.get("WeatherElement", {}).get("Weather", "無資料")

    # 添加資料到列表
    data_list.append({"測站名稱": station_name, "縣市": county, "鄉鎮": town, "天氣": weather})

# 創建 DataFrame
df = pd.DataFrame(data_list)

# 篩選出天氣為「晴」的地點
sunny_places = df[df["天氣"] == "晴"]

# 印結果
print("天氣為晴的地點：")
print("-"*50)
print(sunny_places)
# Out:
# 天氣為晴的地點：
# --------------------------------------------------
#      測站名稱   縣市    鄉鎮 天氣
# 20     澳底  新北市   貢寮區  晴
# 24     北竿  連江縣   北竿鄉  晴
# 25    科教館  臺北市   士林區  晴
# 26   大溪漁港  宜蘭縣   頭城鎮  晴
# 27     石城  宜蘭縣   頭城鎮  晴
# ..    ...  ...   ... ..
# 457  嘉義梅山  嘉義縣   梅山鄉  晴
# 458    里佳  嘉義縣  阿里山鄉  晴
# 459    達邦  嘉義縣  阿里山鄉  晴
# 461    茶山  嘉義縣  阿里山鄉  晴
# 462    棋山  雲林縣   古坑鄉  晴
#
# [242 rows x 4 columns]
